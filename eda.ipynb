# %% [markdown]
# # DATA CLEANING AND EDA

# %%
import pandas as pd
import numpy as np
import pyreadstat
import missingno as msno
import matplotlib.pyplot as plt

# %%
df, metadata = pyreadstat.read_sav('tastdb-exp-2019.sav', apply_value_formats=True, dates_as_pandas_datetime =True)

# %% [markdown]
# The dataset has a 36108 observations and 274 variables

# %%
pd.options.display.max_columns = 280
df.shape
# Out:
# (36108, 274)

# %% [markdown]
# ### Checking the State of the Dataset

# %% [markdown]
# #### Total and Percentage of Missing Data

# %%
pd.set_option("display.max_rows", 280)

# %%
df.shape
# Out:
# (36108, 274)

# %%
mask = df.isnull()
total= mask.sum()
percent = 100*mask.mean()
missing_data = pd.concat([total, percent], axis= 1, join = 'outer', 
                         keys=['count_missing', 'perc_missing'])
missing_data.sort_values(by= 'perc_missing', ascending= False, inplace = True)
missing_data
# Out:
#              count_missing  perc_missing
# ADULT6               36108    100.000000
# CHILD5               36108    100.000000
# INFANT5              36108    100.000000
# INFANT6              36108    100.000000
# ADULT4               36108    100.000000
# FEMALE5              36107     99.997231
# INFANT2              36107     99.997231
# ADULT5               36107     99.997231
# MALE5                36107     99.997231
# ADULT2               36107     99.997231
# CHILD6               36106     99.994461
# FEMALE6              36105     99.991692
# MALE6                36104     99.988922
# CHILD4               36103     99.986153
# FEMALE4              36103     99.986153
# INFANT4              36101     99.980614
# MALE4                36100     99.977844
# DATARR39             36089     99.947380
# DATELAND3            36089     99.947380
# FEMALE2              36084     99.933533
# GIRL6                36082     99.927994
# BOY6                 36082     99.927994
# DATARR40             36081     99.925224
# DATARR41             36079     99.919685
# WOMEN6               36079     99.919685
# MEN6                 36077     99.914146
# CREW                 36068     99.889221
# FEML2IMP             36065     99.880913
# MALE2                36062     99.872604
# GIRL5                36059     99.864296
# ADULT3               36053     99.847679
# MALE2IMP             36053     99.847679
# SLINTEN2             36050     99.839371
# BOY5                 36042     99.817215
# CHILD2               36037     99.803368
# MEN5                 36027     99.775673
# WOMEN5               36026     99.772904
# REGDIS3              36021     99.759056
# ADPSALE2             36021     99.759056
# GIRL4                35986     99.662125
# INFANT1              35984     99.656586
# GIRL2                35981     99.648277
# BOY4                 35974     99.628891
# WOMEN4               35965     99.603966
# MEN4                 35963     99.598427
# REGARR2              35956     99.579041
# ARRPORT2             35954     99.573502
# INFANT3              35948     99.556885
# BOY2                 35926     99.495957
# FEMALE1              35915     99.465492
# MALE1                35913     99.459953
# CHILD3               35852     99.291016
# CHIL2IMP             35842     99.263321
# MEN2                 35818     99.196854
# SLADAFRI             35817     99.194084
# CREW5                35805     99.160851
# CREW2                35801     99.149773
# WOMEN2               35770     99.063919
# ADLT2IMP             35718     98.919907
# FEMALE3              35711     98.900521
# MALE3                35710     98.897751
# DATELAND2            35602     98.598648
# DATARR36             35586     98.554337
# CHILD1               35574     98.521103
# PLAC3TRA             35556     98.471253
# REGEM3               35554     98.465714
# RESISTANCE           35537     98.418633
# DATARR38             35516     98.360474
# DATARR37             35516     98.360474
# GIRL1                35377     97.975518
# ADULT1               35357     97.920129
# SLADAMER             35324     97.828736
# BOY1                 35298     97.756730
# WOMEN1               35236     97.585023
# GIRLRAT1             35209     97.510247
# BOYRAT1              35208     97.507478
# MENRAT1              35207     97.504708
# WOMRAT1              35207     97.504708
# SLAVMAX1             35205     97.499169
# MEN1                 35199     97.482552
# JAMCASPR             35159     97.371774
# EMBREG2              35132     97.296998
# EMBPORT2             35129     97.288689
# FEML1IMP             35044     97.053285
# MALE1IMP             35021     96.989587
# MALRAT1              35018     96.981278
# SLAVEMX1             35017     96.978509
# REGDIS2              34771     96.297219
# ADPSALE1             34769     96.291681
# TSLAVESP             34604     95.834718
# CREW4                34583     95.776559
# CHIL1IMP             34554     95.696245
# ADLT1IMP             34554     95.696245
# CHILRAT1             34531     95.632547
# SLAVEMA1             34529     95.627008
# NPAFTTRA             34426     95.341753
# NCAR17               34245     94.840479
# NCAR15               34225     94.785089
# SAILD1               34172     94.638307
# NCAR13               34152     94.582918
# SAILD3               34100     94.438906
# SAILD5               34057     94.319818
# SAILD4               34043     94.281046
# SAILD2               34039     94.269968
# CREW3                33827     93.682840
# NDESERT              33782     93.558214
# SLAS39               33745     93.455744
# SLAS36               33630     93.137255
# REGEM2               33323     92.287028
# PLAC2TRA             33318     92.273180
# GIRL3                33286     92.184557
# CHIL3IMP             33243     92.065470
# ADLT3IMP             33243     92.065470
# BOY3                 33172     91.868838
# SLAS32               33088     91.636203
# WOMEN3               33079     91.611277
# GIRLRAT3             33072     91.591891
# BOYRAT3              33071     91.589122
# SLAVMAX3             33066     91.575274
# WOMRAT3              33066     91.575274
# MENRAT3              33066     91.575274
# MEN3                 33045     91.517115
# NPPRIOR              33011     91.422953
# CHILRAT3             32992     91.370333
# SLAVEMA3             32989     91.362025
# FEML3IMP             32927     91.190318
# MALE3IMP             32676     90.495181
# MALRAT3              32675     90.492412
# SLAVEMX3             32675     90.492412
# GIRLRAT7             32647     90.414867
# GIRL7                32647     90.414867
# BOYRAT7              32644     90.406558
# BOY7                 32644     90.406558
# MENRAT7              32640     90.395480
# WOMEN7               32640     90.395480
# WOMRAT7              32640     90.395480
# MEN7                 32640     90.395480
# SLAVMAX7             32639     90.392711
# NPPRETRA             32636     90.384402
# SLADVOY              32194     89.160297
# MALE7                32167     89.085521
# MALRAT7              32167     89.085521
# FEMALE7              32167     89.085521
# SLAVEMX7             32167     89.085521
# VOYAGE               32063     88.797496
# CHILD7               31903     88.354381
# CHILRAT7             31903     88.354381
# ADULT7               31902     88.351612
# SLAVEMA7             31900     88.346073
# CREWDIED             31651     87.656475
# YRREG                31191     86.382519
# DATEDEPAM            30462     84.363576
# DDEPAM               30458     84.352498
# DDEPAMB              30359     84.078321
# GUNS                 29923     82.870832
# YRCONS               29847     82.660352
# DDEPAMC              29733     82.344633
# VYMRTRAT             29631     82.062147
# TSLMTIMP             29628     82.053838
# VYMRTIMP             29591     81.951368
# DATEBUY              29481     81.646726
# D1SLATRA             29472     81.621801
# SLINTEND             28811     79.791182
# VOY2IMP              28800     79.760718
# REGISREG             28595     79.192977
# PLACREG              28559     79.093276
# D1SLATRB             28368     78.564307
# DATELEFTAFR          27991     77.520217
# TSLAVESD             27808     77.013404
# DLSLATRA             27703     76.722610
# D1SLATRC             27274     75.534508
# CONSTREG             27035     74.872604
# PLACCONS             26907     74.518112
# DLSLATRB             26658     73.828514
# REGARR               25741     71.288911
# ARRPORT              25709     71.200288
# DATEEND              25654     71.047967
# DATARR43             25642     71.014734
# RETRNREG             25541     70.735017
# RETRNREG1            25398     70.338983
# PORTRET              25356     70.222665
# DATARR44             25234     69.884790
# DLSLATRC             24857     68.840700
# DATARR45             24708     68.428049
# CREW1                23376     64.739116
# VOY1IMP              23046     63.825191
# EMBREG               20451     56.638418
# EMBPORT              20387     56.461172
# TONTYPE              19481     53.952033
# TONMOD               19404     53.738784
# TONNAGE              18439     51.066246
# DATELAND1            17906     49.590119
# DATARR32             17827     49.371330
# SLAARRIV             17747     49.149773
# DATARR33             15000     41.542041
# MAJBUYPT             14150     39.187992
# PLAC1TRA             14037     38.875042
# REGEM1               14033     38.863964
# DATEDEP              13244     36.678852
# DATEDEPA             13225     36.626232
# RIG                  12414     34.380193
# DATEDEPB             12085     33.469037
# DATARR34             11742     32.519109
# MAJSELPT             10404     28.813559
# REGDIS1              10387     28.766478
# SLA1PORT             10386     28.763709
# DATEDEPC              9629     26.667221
# NATIONAL              9538     26.415199
# PORTDEP               6950     19.247812
# PTDEPIMP              4475     12.393375
# DEPTREGIMP1           4475     12.393375
# DEPTREGIMP            4474     12.390606
# MJSELIMP              4267     11.817326
# MJSLPTIMP             4266     11.814556
# MJSELIMP1             4266     11.814556
# NATINIMP              2188      6.059599
# SLAMIMP               1926      5.333998
# MJBYPTIMP             1687      4.672095
# MAJBYIMP              1687      4.672095
# MAJBYIMP1             1687      4.672095
# SLAXIMP               1631      4.517005
# XMIMPFLAG              119      0.329567
# filter_$               119      0.329567
# SHIPNAME                 0      0.000000
# FATE                     0      0.000000
# OWNERG                   0      0.000000
# OWNERF                   0      0.000000
# OWNERE                   0      0.000000
# OWNERD                   0      0.000000
# OWNERC                   0      0.000000
# OWNERB                   0      0.000000
# OWNERA                   0      0.000000
# FATE4                    0      0.000000
# FATE3                    0      0.000000
# FATE2                    0      0.000000
# EVGREEN                  0      0.000000
# OWNERI                   0      0.000000
# CAPTAINC                 0      0.000000
# YEAR5                    0      0.000000
# YEAR10                   0      0.000000
# YEAR25                   0      0.000000
# YEAR100                  0      0.000000
# YEARAF                   0      0.000000
# YEARAM                   0      0.000000
# YEARDEP                  0      0.000000
# CAPTAINB                 0      0.000000
# CAPTAINA                 0      0.000000
# OWNERH                   0      0.000000
# OWNERJ                   0      0.000000
# SOURCEA                  0      0.000000
# SOURCEL                  0      0.000000
# SOURCEB                  0      0.000000
# SOURCEC                  0      0.000000
# SOURCED                  0      0.000000
# SOURCEE                  0      0.000000
# SOURCEF                  0      0.000000
# SOURCEG                  0      0.000000
# SOURCEH                  0      0.000000
# SOURCEI                  0      0.000000
# SOURCEJ                  0      0.000000
# SOURCEK                  0      0.000000
# SOURCEM                  0      0.000000
# OWNERK                   0      0.000000
# SOURCEN                  0      0.000000
# SOURCEO                  0      0.000000
# SOURCEP                  0      0.000000
# SOURCEQ                  0      0.000000
# SOURCER                  0      0.000000
# OWNERP                   0      0.000000
# OWNERO                   0      0.000000
# OWNERN                   0      0.000000
# OWNERM                   0      0.000000
# OWNERL                   0      0.000000
# VOYAGEID                 0      0.000000

# %%
num_missing = missing_data['perc_missing'] > 80

# %%
#num_missing

# %%
miss = missing_data[num_missing].shape
miss
# Out:
# (162, 2)

# %%
per_above_80 = miss[0] / 274

# %%
per_above_80
# Out:
# 0.5912408759124088

# %% [markdown]
# **Basically, 60% of the columns have at least 80% of their data missing. Data science workshops recommend dropping columns that have more than 80% of their data missing.**

# %% [markdown]
# ### Visualizing Missing Data in the Dataset

# %%
nullable_columns = df.columns[mask.any()].tolist()

# %%
fig=msno.matrix(df[nullable_columns].sample(4000))

# %%
fig_copy = fig.get_figure() 

fig_copy.savefig('./Plots and Figures/nullity_matrix.png')

# %%
plt.show()

# %%
fig = msno.bar(df[nullable_columns].sample(4000))

# %%
fig_copy = fig.get_figure() 

fig_copy.savefig('./Plots and Figures/nullity_bar.png')

# %%
fig = msno.dendrogram(df[nullable_columns])

# %%
fig_copy = fig.get_figure() 

fig_copy.savefig('./Plots and Figures/nullity_dendogramm.png')

# %%
# Filtering and Keeping Columns where missing values < 80
#df = df[[col for col in df.columns if 100 * df[col].isnull().sum().mean() < 80]]

# %%
df = df.drop(columns = ['YRCONS', 'YRREG', 'filter_$', 'WOMEN1', 'WOMEN2', 'WOMEN3', 'WOMEN4', 'WOMEN5',
                        'WOMEN6', 'WOMEN7', 'WOMRAT1', 'WOMRAT3', 'WOMRAT7', 'TSLAVESP', 'TSLMTIMP', 'VOY1IMP','VOY2IMP',
                        'VOYAGE', 'VYMRTIMP','SOURCEH', 'SOURCEI', 'SOURCEJ', 'SOURCEK', 'SOURCEL', 'SOURCEM', 'SOURCEN',
                        'SOURCEO', 'SOURCEP', 'SOURCEQ', 'SOURCER', 'SOURCEB', 'SOURCEC', 'SOURCED', 'SOURCEE', 'SOURCEF', 'SOURCEG',
                       'SLAS32', 'SLAS36', 'SLAS39', 'SLAVEMA1', 'SLAVEMA3', 'SLAVEMA7', 'SLAVEMX1', 'SLAVEMX3', 'SLAVEMX7',
                        'SLAVMAX1', 'SLAVMAX3','SLAVMAX7', 'SLINTEN2','SLADAFRI', 'SLADAMER', 'SLADVOY', 'SAILD1', 'SAILD2', 'SAILD3', 
                        'SAILD4', 'SAILD5','REGDIS3', 'REGARR2', 'PLAC2TRA', 'PLAC3TRA', 'OWNERB', 'OWNERC', 'OWNERD', 'OWNERE',
                        'OWNERF', 'OWNERG', 'OWNERH', 'OWNERI', 'OWNERJ', 'OWNERK', 'OWNERL', 'OWNERM', 'OWNERN',
                        'OWNERO', 'OWNERP', 'NCAR13', 'NCAR15', 'NCAR17', 'NDESERT', 'NPAFTTRA', 'NPPRETRA','NPPRIOR',
                         'MALE1', 'MALE2', 'MALE3', 'MALE4', 'MALE5', 'MALE6', 'MALE7','MALE1IMP','MALE2IMP','MALE3IMP','MALRAT1',
                        'MALRAT3', 'MALRAT7', 'MEN1', 'MEN2','MEN3', 'MEN4','MEN5', 'MEN6', 'MEN7','MENRAT1','MENRAT3','MENRAT7', 
                       'INFANT1', 'INFANT2', 'INFANT3', 'INFANT4','INFANT5', 'INFANT6', 'JAMCASPR', 'FEMALE1','FEMALE2', 'FEMALE3',
                        'FEMALE4', 'FEMALE5', 'FEMALE6', 'FEMALE7', 'FEML1IMP','FEML2IMP','FEML3IMP', 'GIRL2','GIRL3', 'GIRL4', 'GIRL5',
                        'GIRL6', 'GIRL7','GIRLRAT1', 'GIRLRAT3','GIRLRAT7', 'EMBPORT2', 'DATARR38', 'DATARR39', 'DATARR40',
                        'DATARR41', 'DATARR36', 'DATARR37', 'DATARR38', 'DATARR39', 'DATARR40', 'DATARR41', 'DATARR43', 'DATARR44',
                       'CREW', 'CREW1', 'CREW2','CREW3','CREW4','CREW5','CREWDIED','CHILRAT3', 'CHILD1', 'CHILD2','CHILD3', 'CHILD4',
                        'CHILD5', 'CHILD6', 'CHILD7', 'CAPTAINB', 'CAPTAINC', 'ARRPORT2', 'BOY1', 'BOY2', 'BOY3', 'BOY4', 'BOY5', 'BOY6', 'BOY7',
                        'BOYRAT1', 'BOYRAT3', 'BOYRAT7','ADPSALE2', 'ADULT1', 'ADULT2','ADULT3','ADULT4','ADULT5','ADULT6','ADULT7',
                        'ADLT2IMP', 'ADLT3IMP'])

# %%
df.sample(2)
# Out:
#        VOYAGEID  ADLT1IMP ADPSALE1 ARRPORT          CAPTAINA  CHIL1IMP  \
# 29691   77539.0       NaN      NaN     NaN  Gunnings, Thomas       NaN
# 30803   80816.0       NaN      NaN     NaN     Crow, William       NaN
#
#        CHIL2IMP  CHIL3IMP  CHILRAT1  CHILRAT7           CONSTREG  D1SLATRA  \
# 29691       NaN       NaN       NaN       NaN   Non-geographical       NaN
# 30803       NaN       NaN       NaN       NaN   Non-geographical       NaN
#
#        D1SLATRB  D1SLATRC  DATARR32  DATARR33  DATARR34  DATARR45  DATEBUY  \
# 29691       NaN       NaN       NaN       NaN    1741.0    1742.0      NaN
# 30803       NaN       NaN       5.0       3.0    1799.0    1799.0      NaN
#
#             DATEDEP  DATEDEPA     DATEDEPAM  DATEDEPB  DATEDEPC       DATEEND  \
# 29691  4.996512e+09      12.0           NaN       2.0    1741.0  5.040490e+09
# 30803  6.813245e+09       8.0  6.834758e+09       9.0    1798.0  6.838560e+09
#
#           DATELAND1  DATELAND2  DATELAND3   DATELEFTAFR  DDEPAM  DDEPAMB  \
# 29691           NaN        NaN        NaN  5.008349e+09     NaN      NaN
# 30803  6.828624e+09        NaN        NaN           NaN    15.0      5.0
#
#        DDEPAMC DEPTREGIMP DEPTREGIMP1  DLSLATRA  DLSLATRB  DLSLATRC EMBPORT  \
# 29691      NaN    England      Europe      29.0       6.0    1741.0     NaN
# 30803   1799.0    England      Europe       NaN       NaN       NaN   Bonny
#
#                                             EMBREG EMBREG2 EVGREEN  \
# 29691                                          NaN     NaN    True
# 30803   Bight of Biafra and Gulf of Guinea islands     NaN    True
#
#                                FATE                        FATE2  \
# 29691  Voyage completed as intended  Slaves disembarked Americas
# 30803  Voyage completed as intended  Slaves disembarked Americas
#
#               FATE3                                 FATE4  GIRL1  GUNS  \
# 29691  Not captured  Delivered slaves for original owners    NaN  12.0
# 30803  Not captured  Delivered slaves for original owners    NaN   NaN
#
#         MAJBUYPT                                     MAJBYIMP MAJBYIMP1  \
# 29691  Gallinhas                                 Sierra Leone    Africa
# 30803      Bonny   Bight of Biafra and Gulf of Guinea islands    Africa
#
#                            MAJSELPT  MJBYPTIMP     MJSELIMP  MJSELIMP1  \
# 29691     Jamaica, port unspecified  Gallinhas      Jamaica  Caribbean
# 30803  Martinique, port unspecified      Bonny   Martinique  Caribbean
#
#                           MJSLPTIMP       NATINIMP       NATIONAL  \
# 29691     Jamaica, port unspecified  Great Britain  Great Britain
# 30803  Martinique, port unspecified  Great Britain  Great Britain
#
#                  OWNERA   PLAC1TRA                   PLACCONS PLACREG  \
# 29691  Gunnings, Thomas  Gallinhas        British plantations  London
# 30803   Taylor, Michael      Bonny  Prize (taken from French)     NaN
#
#          PORTDEP    PORTRET   PTDEPIMP REGARR      REGDIS1 REGDIS2  \
# 29691     London     London     London    NaN      Jamaica     NaN
# 30803  Liverpool  Liverpool  Liverpool    NaN   Martinique     NaN
#
#                                             REGEM1 REGEM2 REGEM3  REGISREG  \
# 29691                                 Sierra Leone    NaN    NaN   England
# 30803   Bight of Biafra and Gulf of Guinea islands    NaN    NaN       NaN
#
#       RESISTANCE  RETRNREG RETRNREG1    RIG          SHIPNAME  \
# 29691        NaN   England    Europe  Snauw  Writtle Merchant
# 30803        NaN   England    Europe   Ship         Charlotte
#
#                            SLA1PORT  SLAARRIV  SLAMIMP  SLAXIMP  SLINTEND  \
# 29691     Jamaica, port unspecified       NaN    197.0    240.0       NaN
# 30803  Martinique, port unspecified     295.0    295.0    322.0     344.0
#
#        SOURCEA  TONMOD  TONNAGE           TONTYPE  TSLAVESD  VYMRTRAT  \
# 29691  ADM7/83   272.3    150.0  English pre-1775       NaN       NaN
# 30803   LR1799   210.0    210.0         English 1       NaN       NaN
#
#              XMIMPFLAG            YEAR5           YEAR10           YEAR25  \
# 29691    Snow, 1726-50    years 1741-45    years 1741-50    years 1726-50
# 30803  Ship, 1776-1800  years 1796-1800  years 1791-1800  years 1776-1800
#
#        YEAR100  YEARAF  YEARAM  YEARDEP
# 29691   1700.0  1741.0  1741.0   1741.0
# 30803   1700.0  1799.0  1799.0   1798.0

# %%
df = df.drop(columns = ['CHIL1IMP','CHIL2IMP','CHIL3IMP','CHIL1IMP','CHIL2IMP', 'CHIL3IMP','CHILRAT7', 'CONSTREG','D1SLATRA','D1SLATRB','D1SLATRC',
                        'DATARR32','DATARR33', 'DATARR45','DATEBUY', 'DATELAND1','DATELAND2','DATELAND3','DATELEFTAFR','DDEPAM','DDEPAMB','DDEPAMC',
                       'DLSLATRA', 'DLSLATRB', 'DLSLATRC','EMBPORT','EMBREG','EMBREG2'])

# %%
df.sample(50)
# Out:
#        VOYAGEID  ADLT1IMP                      ADPSALE1  \
# 32064   82396.0       NaN                           NaN
# 27747   51019.0       NaN                           NaN
# 14943   29248.0       NaN                           NaN
# 18591   33116.0       NaN                           NaN
# 7775    11291.0       NaN                           NaN
# 4197     4389.0       NaN                           NaN
# 28558   51924.0       NaN                           NaN
# 11174   19186.0       NaN                           NaN
# 21460   40490.0       NaN                           NaN
# 22841   42173.0       NaN                           NaN
# 12219   21155.0       NaN                           NaN
# 18671   33197.0       NaN                           NaN
# 1291     1309.0       NaN                           NaN
# 26806   50044.0       NaN                           NaN
# 17825   32306.0       NaN                           NaN
# 5860     8667.0     504.0                           NaN
# 4770     5504.0       NaN                         31202
# 17360   31827.0       NaN                           NaN
# 27353   50611.0       NaN                           NaN
# 16130   30569.0       NaN                           NaN
# 16999   31449.0       NaN                           NaN
# 7271    10734.0       NaN                           NaN
# 16170   30609.0       NaN                           NaN
# 18989   33786.0       NaN                           NaN
# 9929    17078.0       NaN                           NaN
# 34493   91271.0       NaN                           NaN
# 26457   49654.0       NaN                           NaN
# 12856   24342.0       NaN                           NaN
# 34939   91728.0       NaN     Grenada, port unspecified
# 25592   48670.0       NaN                           NaN
# 5624     8426.0     544.0                           NaN
# 15738   30176.0       NaN                           NaN
# 17127   31578.0       NaN                           NaN
# 26032   49177.0     446.0                           NaN
# 26506   49703.0       NaN                           NaN
# 29207   76499.0       NaN                           NaN
# 23692   44300.0       NaN                           NaN
# 3464     3652.0       NaN                           NaN
# 35144   91936.0       NaN                           NaN
# 2377     2409.0     134.0                           NaN
# 36009  900131.0       NaN                           NaN
# 12973   24615.0       NaN                           NaN
# 1877     1901.0       NaN                           NaN
# 15441   29827.0       NaN                           NaN
# 30504   80430.0       NaN                           NaN
# 16780   31223.0       NaN                           NaN
# 21494   40556.0       NaN                           NaN
# 10053   17203.0       NaN                           NaN
# 16949   31394.0       NaN  Guadaloupe, port unspecified
# 12125   21047.0       NaN                           NaN
#
#                              ARRPORT                         CAPTAINA  \
# 32064                            NaN                   Harney, Thomas
# 27747        Bahia, port unspecified
# 14943                            NaN                Acosta, Jacome de
# 18591                            NaN                    Laudouine, de
# 7775                             NaN
# 4197                             NaN
# 28558                            NaN  Vasconcelos, Antônio Ribeiro de
# 11174                 Rio de Janeiro           Silva, Antônio José da
# 21460                            NaN          Torres, Manoel da Silva
# 22841                            NaN              Robles, Juan Martin
# 12219                            NaN                  Corbin, Francis
# 18671                            NaN                    Carré, Pierre
# 1291                             NaN              Pequeño, Jose Maria
# 26806        Bahia, port unspecified           Cruz, João Pinheiro da
# 17825                            NaN                       Dubourg, P
# 5860                  Rio de Janeiro        Cruz, Francisco Xavier da
# 4770                             NaN                  Carrera, Benito
# 17360                            NaN                   Chemin, Julien
# 27353        Bahia, port unspecified                   Ferreira, João
# 16130                            NaN              Delahaye, Fr-Pierre
# 16999                            NaN                   Robert, Pierre
# 7271                        Suriname                Beekman, Godfried
# 16170                            NaN                   Ollier, Joseph
# 18989                            NaN                   Darnes, Marcel
# 9929                             NaN                     Codd, Robert
# 34493      Jamaica, port unspecified               Harrison, Jonathan
# 26457                            NaN       Guimarães, Silvestre de Sá
# 12856                            NaN
# 34939                            NaN                   Hughes, Joseph
# 25592                            NaN           Braga, Isidoro Martins
# 5624         Bahia, port unspecified       Rosario, Inácio Antunes do
# 15738                            NaN                 Lavigne, Achille
# 17127                            NaN          Carles, François-Xavier
# 26032                 Rio de Janeiro          Lisboa, Antônio Pereira
# 26506                            NaN                    Basílio, João
# 29207                            NaN              Stibbs, Bartholomew
# 23692                            NaN                de Orrego, Benito
# 3464                             NaN                 Carvalho, A P de
# 35144  St. Vincent, port unspecified               Richardson, Samuel
# 2377                          Havana               Vega, Miguel de la
# 36009                            NaN
# 12973      Jamaica, port unspecified                    Mason, Joseph
# 1877                             NaN                Viana, José Maria
# 15441                            NaN                  Antunez, Manuel
# 30504                            NaN                  Harrocks, James
# 16780                            NaN                       Chevy, J-B
# 21494                            NaN
# 10053                            NaN                Graham, Alexander
# 16949                            NaN                     Reynaud, Ant
# 12125                            NaN                        Sumerfiel
#
#        CHILRAT1  DATARR34       DATEDEP  DATEDEPA     DATEDEPAM  DATEDEPB  \
# 32064       NaN    1804.0  6.998832e+09      27.0           NaN       7.0
# 27747       NaN       NaN           NaN       NaN           NaN       NaN
# 14943       NaN    1619.0  1.089418e+09      22.0           NaN       4.0
# 18591       NaN    1719.0           NaN       NaN           NaN       8.0
# 7775        NaN    1637.0           NaN       NaN           NaN       NaN
# 4197        NaN    1861.0           NaN       NaN           NaN       NaN
# 28558       NaN       NaN  4.523213e+09      13.0           NaN       2.0
# 11174       NaN    1804.0  6.941290e+09      30.0           NaN       9.0
# 21460       NaN    1798.0           NaN       NaN           NaN       NaN
# 22841       NaN       NaN  7.193146e+09      23.0           NaN       9.0
# 12219       NaN    1704.0  3.813005e+09      13.0           NaN       8.0
# 18671       NaN    1754.0  5.374253e+09       1.0  5.412701e+09       2.0
# 1291        NaN    1834.0           NaN       NaN           NaN       NaN
# 26806       NaN       NaN  3.515011e+09       3.0           NaN       3.0
# 17825       NaN    1777.0  6.099581e+09      27.0           NaN       1.0
# 5860    0.08696       NaN           NaN       NaN           NaN       NaN
# 4770        NaN    1818.0           NaN       NaN           NaN       NaN
# 17360       NaN       NaN  6.625584e+09      27.0           NaN       9.0
# 27353       NaN    1734.0  4.758480e+09      29.0           NaN       7.0
# 16130       NaN    1750.0  5.276794e+09      31.0           NaN      12.0
# 16999       NaN    1740.0  4.925750e+09      16.0  4.989427e+09      11.0
# 7271        NaN    1757.0  5.478624e+09      24.0  5.507827e+09       5.0
# 16170       NaN    1752.0  5.334163e+09      26.0  5.368982e+09      10.0
# 18989       NaN       NaN  3.251664e+09      28.0           NaN      10.0
# 9929        NaN       NaN  5.042045e+09      24.0  5.062262e+09       7.0
# 34493       NaN    1758.0           NaN       NaN           NaN       NaN
# 26457       NaN    1777.0           NaN       NaN           NaN       NaN
# 12856       NaN       NaN           NaN       NaN           NaN       4.0
# 34939       NaN    1777.0  6.112800e+09      28.0           NaN       6.0
# 25592       NaN    1818.0           NaN       NaN           NaN       NaN
# 5624    0.00000       NaN  6.929107e+09      12.0           NaN       5.0
# 15738       NaN    1722.0  4.402080e+09      13.0  4.441392e+09       4.0
# 17127       NaN    1771.0  5.939654e+09       2.0           NaN       1.0
# 26032   0.00000       NaN           NaN       NaN           NaN       NaN
# 26506       NaN    1728.0           NaN       NaN           NaN       NaN
# 29207       NaN    1717.0           NaN       NaN           NaN       NaN
# 23692       NaN    1612.0           NaN       NaN           NaN       NaN
# 3464        NaN       NaN           NaN       NaN           NaN       NaN
# 35144       NaN    1774.0  6.037027e+09       2.0  6.065626e+09       2.0
# 2377    0.27568    1830.0  7.790774e+09      31.0           NaN       8.0
# 36009       NaN       NaN  7.737984e+09      29.0           NaN      12.0
# 12973       NaN    1766.0  5.763485e+09       3.0  5.788886e+09       6.0
# 1877        NaN    1839.0           NaN       NaN           NaN       NaN
# 15441       NaN       NaN           NaN       NaN           NaN       NaN
# 30504       NaN    1792.0  6.598454e+09      18.0  6.618067e+09      11.0
# 16780       NaN    1788.0  6.450710e+09      14.0           NaN       3.0
# 21494       NaN    1823.0           NaN       NaN           NaN       NaN
# 10053       NaN    1748.0  5.216227e+09      30.0  5.254330e+09       1.0
# 16949       NaN    1792.0  6.592234e+09       7.0           NaN       9.0
# 12125       NaN       NaN           NaN       NaN           NaN       NaN
#
#        DATEDEPC       DATEEND         DEPTREGIMP DEPTREGIMP1 EVGREEN  \
# 32064    1804.0           NaN            England      Europe    True
# 27747    1776.0           NaN              Bahia      Brazil    True
# 14943    1617.0           NaN              Spain      Europe    True
# 18591    1718.0           NaN             France      Europe    True
# 7775        NaN           NaN         Pernambuco      Brazil   False
# 4197        NaN           NaN                NaN         NaN    True
# 28558    1726.0           NaN              Bahia      Brazil   False
# 11174    1802.0           NaN   Southeast Brazil      Brazil    True
# 21460       NaN           NaN              Bahia      Brazil   False
# 22841    1810.0           NaN               Cuba   Caribbean   False
# 12219    1703.0           NaN            England      Europe    True
# 18671    1753.0  5.416848e+09             France      Europe    True
# 1291        NaN           NaN                NaN         NaN    True
# 26806    1694.0           NaN              Bahia      Brazil    True
# 17825    1776.0  6.145373e+09             France      Europe    True
# 5860        NaN           NaN           Portugal      Europe    True
# 4770        NaN           NaN                NaN         NaN   False
# 17360    1792.0           NaN             France      Europe    True
# 27353    1733.0           NaN              Bahia      Brazil    True
# 16130    1749.0           NaN             France      Europe    True
# 16999    1738.0  4.996685e+09             France      Europe    True
# 7271     1756.0  5.513098e+09        Netherlands      Europe    True
# 16170    1751.0  5.374339e+09             France      Europe    True
# 18989    1685.0           NaN             France      Europe   False
# 9929     1742.0  5.066842e+09            England      Europe    True
# 34493    1757.0           NaN            England      Europe    True
# 26457       NaN           NaN              Bahia      Brazil   False
# 12856    1717.0           NaN            England      Europe   False
# 34939    1776.0  6.152717e+09            England      Europe    True
# 25592       NaN           NaN              Bahia      Brazil   False
# 5624     1802.0           NaN   Southeast Brazil      Brazil   False
# 15738    1722.0  4.445626e+09             France      Europe    True
# 17127    1771.0           NaN             France      Europe    True
# 26032       NaN           NaN   Southeast Brazil      Brazil   False
# 26506       NaN           NaN              Bahia      Brazil   False
# 29207       NaN  4.276195e+09            England      Europe    True
# 23692       NaN           NaN                NaN         NaN   False
# 3464        NaN           NaN   Southeast Brazil      Brazil    True
# 35144    1774.0  6.069254e+09            England      Europe    True
# 2377     1829.0           NaN               Cuba   Caribbean    True
# 36009    1827.0           NaN   Southeast Brazil      Brazil   False
# 12973    1765.0           NaN            England      Europe    True
# 1877        NaN           NaN   Southeast Brazil      Brazil    True
# 15441    1609.0           NaN                NaN         NaN   False
# 30504    1791.0  6.620659e+09            England      Europe    True
# 16780    1787.0  6.511363e+09             France      Europe    True
# 21494       NaN           NaN         Pernambuco      Brazil   False
# 10053    1748.0  5.259946e+09            England      Europe    True
# 16949    1791.0  6.631546e+09             France      Europe    True
# 12125       NaN           NaN                NaN         NaN    True
#
#                                                     FATE  \
# 32064     Shipwrecked or destroyed, after disembarkation
# 27747                  Left home port, no further record
# 14943  Shipwrecked or destroyed, after embarkation of...
# 18591                       Voyage completed as intended
# 7775   Sold slaves in Americas - subsequent fate unknown
# 4197                        Voyage completed as intended
# 28558                  Left home port, no further record
# 11174                       Voyage completed as intended
# 21460  Sold slaves in Americas - subsequent fate unknown
# 22841                  Left home port, no further record
# 12219                       Voyage completed as intended
# 18671                       Voyage completed as intended
# 1291                        Voyage completed as intended
# 26806                  Left home port, no further record
# 17825                       Voyage completed as intended
# 5860   Bought at least one slave in Africa - subseque...
# 4770                        Voyage completed as intended
# 17360       Captured by British - before slaves embarked
# 27353                       Voyage completed as intended
# 16130                            Condemned - unspecified
# 16999                       Voyage completed as intended
# 7271                        Voyage completed as intended
# 16170                       Voyage completed as intended
# 18989                  Left home port, no further record
# 9929                        Voyage completed as intended
# 34493  Sold slaves in Americas - subsequent fate unknown
# 26457                       Voyage completed as intended
# 12856                  Left home port, no further record
# 34939                       Voyage completed as intended
# 25592                       Voyage completed as intended
# 5624   Bought at least one slave in Africa - subseque...
# 15738                       Voyage completed as intended
# 17127  Sold slaves in Americas - subsequent fate unknown
# 26032         Arrived in Africa, subsequent fate unknown
# 26506  Sold slaves in Americas - subsequent fate unknown
# 29207                       Voyage completed as intended
# 23692  Sold slaves in Americas - subsequent fate unknown
# 3464         Vice-Admiralty Court, St.Helena,  condemned
# 35144                       Voyage completed as intended
# 2377   Court of Mixed Commission, Sierra Leone, conde...
# 36009                  Left home port, no further record
# 12973  Sold slaves in Americas - subsequent fate unknown
# 1877                        Voyage completed as intended
# 15441                  Left home port, no further record
# 30504                       Voyage completed as intended
# 16780                       Voyage completed as intended
# 21494  Sold slaves in Americas - subsequent fate unknown
# 10053                       Voyage completed as intended
# 16949                       Voyage completed as intended
# 12125       Captured by British - before slaves embarked
#
#                                                    FATE2           FATE3  \
# 32064                        Slaves disembarked Americas  Natural hazard
# 27747                           No information on slaves         Unknown
# 14943                          Slaves perished with ship  Natural hazard
# 18591                        Slaves disembarked Americas    Not captured
# 7775                         Slaves disembarked Americas    Not captured
# 4197                         Slaves disembarked Americas    Not captured
# 28558                           No information on slaves         Unknown
# 11174                        Slaves disembarked Americas    Not captured
# 21460                        Slaves disembarked Americas    Not captured
# 22841                           No information on slaves         Unknown
# 12219                        Slaves disembarked Americas    Not captured
# 18671                        Slaves disembarked Americas    Not captured
# 1291                         Slaves disembarked Americas    Not captured
# 26806                           No information on slaves         Unknown
# 17825                        Slaves disembarked Americas    Not captured
# 5860   Slaves embarked, transhipped or no further record    Not captured
# 4770                         Slaves disembarked Americas    Not captured
# 17360                                 No slaves embarked         British
# 27353                        Slaves disembarked Americas    Not captured
# 16130                        Slaves disembarked Americas  Natural hazard
# 16999                        Slaves disembarked Americas    Not captured
# 7271                         Slaves disembarked Americas    Not captured
# 16170                        Slaves disembarked Americas    Not captured
# 18989                           No information on slaves         Unknown
# 9929                         Slaves disembarked Americas    Not captured
# 34493                        Slaves disembarked Americas    Not captured
# 26457                        Slaves disembarked Americas    Not captured
# 12856                           No information on slaves         Unknown
# 34939                        Slaves disembarked Americas    Not captured
# 25592                        Slaves disembarked Americas    Not captured
# 5624   Slaves embarked, transhipped or no further record    Not captured
# 15738                        Slaves disembarked Americas    Not captured
# 17127                        Slaves disembarked Americas    Not captured
# 26032  Slaves embarked, transhipped or no further record    Not captured
# 26506                        Slaves disembarked Americas    Not captured
# 29207                        Slaves disembarked Americas    Not captured
# 23692                        Slaves disembarked Americas    Not captured
# 3464                                  No slaves embarked         British
# 35144                        Slaves disembarked Americas    Not captured
# 2377                 Slaves disembarked in Africa/Europe         British
# 36009                           No information on slaves         Unknown
# 12973                        Slaves disembarked Americas    Not captured
# 1877                         Slaves disembarked Americas    Not captured
# 15441                           No information on slaves         Unknown
# 30504                        Slaves disembarked Americas    Not captured
# 16780                        Slaves disembarked Americas    Not captured
# 21494                        Slaves disembarked Americas    Not captured
# 10053                        Slaves disembarked Americas    Not captured
# 16949                        Slaves disembarked Americas    Not captured
# 12125                                 No slaves embarked         British
#
#                                          FATE4  GIRL1  GUNS  \
# 32064  Original goal thwarted (natural hazard)    NaN   NaN
# 27747                          Unknown outcome    NaN   NaN
# 14943  Original goal thwarted (natural hazard)    NaN   NaN
# 18591     Delivered slaves for original owners    NaN   NaN
# 7775      Delivered slaves for original owners    NaN   NaN
# 4197      Delivered slaves for original owners    NaN   NaN
# 28558                          Unknown outcome    NaN   NaN
# 11174     Delivered slaves for original owners    NaN   NaN
# 21460     Delivered slaves for original owners    NaN   NaN
# 22841                          Unknown outcome    NaN   NaN
# 12219     Delivered slaves for original owners    NaN  10.0
# 18671     Delivered slaves for original owners    NaN   NaN
# 1291      Delivered slaves for original owners    NaN   NaN
# 26806                          Unknown outcome    NaN   NaN
# 17825     Delivered slaves for original owners    NaN   NaN
# 5860   Original goal thwarted (natural hazard)    NaN   NaN
# 4770      Delivered slaves for original owners    NaN   NaN
# 17360    Original goal thwarted (human agency)    NaN   NaN
# 27353     Delivered slaves for original owners    NaN   NaN
# 16130  Original goal thwarted (natural hazard)    NaN   NaN
# 16999     Delivered slaves for original owners    NaN   NaN
# 7271      Delivered slaves for original owners    NaN   NaN
# 16170     Delivered slaves for original owners    NaN   NaN
# 18989                          Unknown outcome    NaN   NaN
# 9929      Delivered slaves for original owners    NaN   6.0
# 34493     Delivered slaves for original owners    NaN  10.0
# 26457     Delivered slaves for original owners    NaN   NaN
# 12856                          Unknown outcome    NaN   NaN
# 34939     Delivered slaves for original owners    NaN   4.0
# 25592     Delivered slaves for original owners    NaN   NaN
# 5624   Original goal thwarted (natural hazard)    NaN   NaN
# 15738     Delivered slaves for original owners    NaN   NaN
# 17127     Delivered slaves for original owners    NaN   NaN
# 26032     Delivered slaves for original owners    NaN   NaN
# 26506     Delivered slaves for original owners    NaN   NaN
# 29207     Delivered slaves for original owners    NaN   8.0
# 23692     Delivered slaves for original owners    NaN   NaN
# 3464     Original goal thwarted (human agency)    NaN   NaN
# 35144     Delivered slaves for original owners    NaN   4.0
# 2377     Original goal thwarted (human agency)   13.0   NaN
# 36009                          Unknown outcome    NaN   NaN
# 12973     Delivered slaves for original owners    NaN   6.0
# 1877      Delivered slaves for original owners    NaN   NaN
# 15441                          Unknown outcome    NaN   NaN
# 30504     Delivered slaves for original owners    NaN   NaN
# 16780     Delivered slaves for original owners    NaN   NaN
# 21494     Delivered slaves for original owners    NaN   NaN
# 10053     Delivered slaves for original owners    NaN   4.0
# 16949     Delivered slaves for original owners    NaN   NaN
# 12125    Original goal thwarted (human agency)    NaN   NaN
#
#                                                 MAJBUYPT  \
# 32064                                                NaN
# 27747                                                NaN
# 14943  West Central Africa and St. Helena, port unspe...
# 18591                                             Whydah
# 7775   Bight of Biafra and Gulf of Guinea Islands, po...
# 4197                                                 NaN
# 28558                                                NaN
# 11174                                           Benguela
# 21460                                      Costa da Mina
# 22841                                                NaN
# 12219                       Gold Coast, port unspecified
# 18671  West Central Africa and St. Helena, port unspe...
# 1291                                                 NaN
# 26806                                                NaN
# 17825                                            Badagry
# 5860                                  St. Paul de Loanda
# 4770                                                 NaN
# 17360                                                NaN
# 27353                                      Costa da Mina
# 16130                   Windward Coast, port unspecified
# 16999                                                NaN
# 7271                                              Elmina
# 16170                                             Loango
# 18989                                                NaN
# 9929                                                 NaN
# 34493                                              Bonny
# 26457                                             Whydah
# 12856                                                NaN
# 34939                                                NaN
# 25592                                            Malembo
# 5624                                  St. Paul de Loanda
# 15738                                             Loango
# 17127                                             Gambia
# 26032                                                NaN
# 26506                                      Costa da Mina
# 29207                                                NaN
# 23692                                 St. Paul de Loanda
# 3464                                                 NaN
# 35144                                          Cameroons
# 2377                                        Little Bassa
# 36009                                                NaN
# 12973                                                NaN
# 1877   West Central Africa and St. Helena, port unspe...
# 15441                                                NaN
# 30504                                              Bonny
# 16780  West Central Africa and St. Helena, port unspe...
# 21494                                           São Tomé
# 10053                       Gold Coast, port unspecified
# 16949                                             Whydah
# 12125                                                NaN
#
#                                           MAJBYIMP MAJBYIMP1  \
# 32064                                 Other Africa    Africa
# 27747                               Bight of Benin    Africa
# 14943           West Central Africa and St. Helena    Africa
# 18591                               Bight of Benin    Africa
# 7775    Bight of Biafra and Gulf of Guinea islands    Africa
# 4197                                  Other Africa    Africa
# 28558   Bight of Biafra and Gulf of Guinea islands    Africa
# 11174           West Central Africa and St. Helena    Africa
# 21460                               Bight of Benin    Africa
# 22841                                 Other Africa    Africa
# 12219                                   Gold Coast    Africa
# 18671           West Central Africa and St. Helena    Africa
# 1291                                  Other Africa    Africa
# 26806           West Central Africa and St. Helena    Africa
# 17825                               Bight of Benin    Africa
# 5860            West Central Africa and St. Helena    Africa
# 4770    Bight of Biafra and Gulf of Guinea islands    Africa
# 17360                                          NaN       NaN
# 27353                               Bight of Benin    Africa
# 16130                               Windward Coast    Africa
# 16999                                 Other Africa    Africa
# 7271                                    Gold Coast    Africa
# 16170           West Central Africa and St. Helena    Africa
# 18989                               Bight of Benin    Africa
# 9929                                  Other Africa    Africa
# 34493   Bight of Biafra and Gulf of Guinea islands    Africa
# 26457                               Bight of Benin    Africa
# 12856                                 Other Africa    Africa
# 34939                               Windward Coast    Africa
# 25592           West Central Africa and St. Helena    Africa
# 5624            West Central Africa and St. Helena    Africa
# 15738           West Central Africa and St. Helena    Africa
# 17127             Senegambia and offshore Atlantic    Africa
# 26032           West Central Africa and St. Helena    Africa
# 26506                               Bight of Benin    Africa
# 29207                                 Other Africa    Africa
# 23692           West Central Africa and St. Helena    Africa
# 3464                                           NaN       NaN
# 35144   Bight of Biafra and Gulf of Guinea islands    Africa
# 2377                                Windward Coast    Africa
# 36009           West Central Africa and St. Helena    Africa
# 12973                                 Other Africa    Africa
# 1877            West Central Africa and St. Helena    Africa
# 15441                                 Other Africa    Africa
# 30504   Bight of Biafra and Gulf of Guinea islands    Africa
# 16780           West Central Africa and St. Helena    Africa
# 21494   Bight of Biafra and Gulf of Guinea islands    Africa
# 10053                                   Gold Coast    Africa
# 16949                               Bight of Benin    Africa
# 12125                                          NaN       NaN
#
#                            MAJSELPT  \
# 32064                    Charleston
# 27747                           NaN
# 14943                      Veracruz
# 18591                     Louisiana
# 7775   Pernambuco, port unspecified
# 4197         Cuba, port unspecified
# 28558                           NaN
# 11174                Rio de Janeiro
# 21460       Bahia, port unspecified
# 22841                           NaN
# 12219     Jamaica, port unspecified
# 18671                  Cap Français
# 1291         Cuba, port unspecified
# 26806                           NaN
# 17825                    Saint-Marc
# 5860                            NaN
# 4770                          31202
# 17360                           NaN
# 27353       Bahia, port unspecified
# 16130  Martinique, port unspecified
# 16999                   Cayes (Les)
# 7271                       Suriname
# 16170                  Cap Français
# 18989                           NaN
# 9929    St. Kitts, port unspecified
# 34493   St. Kitts, port unspecified
# 26457       Bahia, port unspecified
# 12856                           NaN
# 34939     Grenada, port unspecified
# 25592       Bahia, port unspecified
# 5624                            NaN
# 15738  Martinique, port unspecified
# 17127                  Cap Français
# 26032                           NaN
# 26506       Bahia, port unspecified
# 29207    Barbados, port unspecified
# 23692                  Buenos Aires
# 3464                            NaN
# 35144   St. Kitts, port unspecified
# 2377                       Freetown
# 36009                           NaN
# 12973                      Kingston
# 1877                          Macaé
# 15441                           NaN
# 30504    Dominica, port unspecified
# 16780                  Cap Français
# 21494  Pernambuco, port unspecified
# 10053                      Kingston
# 16949  Guadaloupe, port unspecified
# 12125                           NaN
#
#                                                MJBYPTIMP  \
# 32064                          Africa., port unspecified
# 27747                                      Costa da Mina
# 14943                                 St. Paul de Loanda
# 18591                                             Whydah
# 7775   Bight of Biafra and Gulf of Guinea Islands, po...
# 4197                           Africa., port unspecified
# 28558                                           São Tomé
# 11174                                           Benguela
# 21460                                      Costa da Mina
# 22841                          Africa., port unspecified
# 12219                       Gold Coast, port unspecified
# 18671  West Central Africa and St. Helena, port unspe...
# 1291                           Africa., port unspecified
# 26806                                 St. Paul de Loanda
# 17825                                            Badagry
# 5860                                  St. Paul de Loanda
# 4770   Costa de Africa (mainland coast around S Tome/...
# 17360                                                NaN
# 27353                                      Costa da Mina
# 16130                   Windward Coast, port unspecified
# 16999                          Africa., port unspecified
# 7271                                              Elmina
# 16170                                             Loango
# 18989                   Bight of Benin, port unspecified
# 9929                           Africa., port unspecified
# 34493                                              Bonny
# 26457                                             Whydah
# 12856                          Africa., port unspecified
# 34939                   Windward Coast, port unspecified
# 25592                                            Malembo
# 5624                                  St. Paul de Loanda
# 15738                                             Loango
# 17127                                             Gambia
# 26032                                           Benguela
# 26506                                      Costa da Mina
# 29207                          Africa., port unspecified
# 23692                                 St. Paul de Loanda
# 3464                                                 NaN
# 35144                                          Cameroons
# 2377                                        Little Bassa
# 36009                                            Cabinda
# 12973                          Africa., port unspecified
# 1877                                  St. Paul de Loanda
# 15441                          Africa., port unspecified
# 30504                                              Bonny
# 16780  West Central Africa and St. Helena, port unspe...
# 21494                                           São Tomé
# 10053                       Gold Coast, port unspecified
# 16949                                             Whydah
# 12125                                                NaN
#
#                         MJSELIMP                 MJSELIMP1  \
# 32064             South Carolina    Mainland North America
# 27747                      Bahia                    Brazil
# 14943   Spanish Circum-Caribbean  Spanish Mainland America
# 18591                 Gulf coast    Mainland North America
# 7775                  Pernambuco                    Brazil
# 4197                        Cuba                 Caribbean
# 28558                      Bahia                    Brazil
# 11174           Southeast Brazil                    Brazil
# 21460                      Bahia                    Brazil
# 22841                        NaN                       NaN
# 12219                    Jamaica                 Caribbean
# 18671             Saint-Domingue                 Caribbean
# 1291                        Cuba                 Caribbean
# 26806                      Bahia                    Brazil
# 17825             Saint-Domingue                 Caribbean
# 5860            Southeast Brazil                    Brazil
# 4770                 Puerto Rico                 Caribbean
# 17360                        NaN                       NaN
# 27353                      Bahia                    Brazil
# 16130                 Martinique                 Caribbean
# 16999             Saint-Domingue                 Caribbean
# 7271               Dutch Guianas                 Caribbean
# 16170             Saint-Domingue                 Caribbean
# 18989                        NaN                       NaN
# 9929                   St. Kitts                 Caribbean
# 34493                  St. Kitts                 Caribbean
# 26457                      Bahia                    Brazil
# 12856                        NaN                       NaN
# 34939                    Grenada                 Caribbean
# 25592                      Bahia                    Brazil
# 5624                       Bahia                    Brazil
# 15738                 Martinique                 Caribbean
# 17127             Saint-Domingue                 Caribbean
# 26032           Southeast Brazil                    Brazil
# 26506                      Bahia                    Brazil
# 29207                   Barbados                 Caribbean
# 23692            Rio de la Plata  Spanish Mainland America
# 3464                         NaN                       NaN
# 35144                  St. Kitts                 Caribbean
# 2377                Sierra Leone                    Africa
# 36009           Southeast Brazil                    Brazil
# 12973                    Jamaica                 Caribbean
# 1877            Southeast Brazil                    Brazil
# 15441                        NaN                       NaN
# 30504                   Dominica                 Caribbean
# 16780             Saint-Domingue                 Caribbean
# 21494                 Pernambuco                    Brazil
# 10053                    Jamaica                 Caribbean
# 16949                 Guadaloupe                 Caribbean
# 12125                        NaN                       NaN
#
#                           MJSLPTIMP           NATINIMP       NATIONAL  \
# 32064                    Charleston      Great Britain  Great Britain
# 27747       Bahia, port unspecified  Portugal / Brazil       Portugal
# 14943                      Veracruz  Portugal / Brazil       Portugal
# 18591                     Louisiana             France         France
# 7775   Pernambuco, port unspecified        Netherlands    Netherlands
# 4197         Cuba, port unspecified                NaN            NaN
# 28558       Bahia, port unspecified  Portugal / Brazil            NaN
# 11174                Rio de Janeiro  Portugal / Brazil       Portugal
# 21460       Bahia, port unspecified  Portugal / Brazil            NaN
# 22841                           NaN    Spain / Uruguay          Spain
# 12219     Jamaica, port unspecified      Great Britain  Great Britain
# 18671                  Cap Français             France         France
# 1291         Cuba, port unspecified    Spain / Uruguay          Spain
# 26806       Bahia, port unspecified  Portugal / Brazil       Portugal
# 17825                    Saint-Marc             France         France
# 5860                 Rio de Janeiro  Portugal / Brazil       Portugal
# 4770                       San Juan  Portugal / Brazil       Portugal
# 17360                           NaN             France         France
# 27353       Bahia, port unspecified  Portugal / Brazil       Portugal
# 16130  Martinique, port unspecified             France         France
# 16999                   Cayes (Les)             France         France
# 7271                       Suriname        Netherlands    Netherlands
# 16170                  Cap Français             France         France
# 18989                           NaN             France            NaN
# 9929    St. Kitts, port unspecified      Great Britain  Great Britain
# 34493   St. Kitts, port unspecified      Great Britain  Great Britain
# 26457       Bahia, port unspecified  Portugal / Brazil            NaN
# 12856                           NaN      Great Britain            NaN
# 34939     Grenada, port unspecified      Great Britain  Great Britain
# 25592       Bahia, port unspecified  Portugal / Brazil            NaN
# 5624        Bahia, port unspecified  Portugal / Brazil       Portugal
# 15738  Martinique, port unspecified             France         France
# 17127                  Cap Français             France         France
# 26032                Rio de Janeiro  Portugal / Brazil            NaN
# 26506       Bahia, port unspecified  Portugal / Brazil            NaN
# 29207    Barbados, port unspecified      Great Britain  Great Britain
# 23692                  Buenos Aires    Spain / Uruguay          Spain
# 3464                            NaN  Portugal / Brazil            NaN
# 35144   St. Kitts, port unspecified      Great Britain  Great Britain
# 2377                       Freetown    Spain / Uruguay          Spain
# 36009                Rio de Janeiro  Portugal / Brazil            NaN
# 12973                      Kingston      Great Britain  Great Britain
# 1877                          Macaé  Portugal / Brazil       Portugal
# 15441                           NaN                NaN            NaN
# 30504    Dominica, port unspecified      Great Britain  Great Britain
# 16780                  Cap Français             France         France
# 21494  Pernambuco, port unspecified  Portugal / Brazil            NaN
# 10053                      Kingston      Great Britain  Great Britain
# 16949                   Basse-Terre             France         France
# 12125                           NaN      Great Britain  Great Britain
#
#                               OWNERA  \
# 32064                Leyland, Thomas
# 27747     Marques, Antônio Gonçalves
# 14943
# 18591           Gaillard de La Motte
# 7775
# 4197                       Ducouran*
# 28558
# 11174
# 21460  Seixas, Joaquim José da Silva
# 22841
# 12219               Dunckley, Robert
# 18671                Surcouf, Robert
# 1291
# 26806
# 17825                   Vivier, Elie
# 5860
# 4770
# 17360                      Schovers*
# 27353     Pacheco, Domingos Ferreira
# 16130                Bernier (Fils)*
# 16999                 Marchais, Jean
# 7271                        Coopstad
# 16170                      Wailch, A
# 18989      Compagnie Royal de Guynee
# 9929                Lougher, Walter*
# 34493                 Coupland, John
# 26457
# 12856
# 34939                 James, William
# 25592                   Soares, José
# 5624
# 15738                    Tatin, Jean
# 17127       Collisson, Jean (& Cie)*
# 26032
# 26506                 Dansaint, João
# 29207
# 23692
# 3464      Mota, Manoel José dos Reis
# 35144             Staniforth, Thomas
# 2377
# 36009
# 12973                 Kelsick, John*
# 1877
# 15441
# 30504                 Tarleton, John
# 16780                        Libault
# 21494
# 10053               Gordon, William*
# 16949                          Simon
# 12125
#
#                                                 PLAC1TRA  \
# 32064                                                NaN
# 27747                                                NaN
# 14943  West Central Africa and St. Helena, port unspe...
# 18591                                             Whydah
# 7775                                              Mouree
# 4197                                                 NaN
# 28558                                                NaN
# 11174                                           Benguela
# 21460                                      Costa da Mina
# 22841                                                NaN
# 12219                       Gold Coast, port unspecified
# 18671  West Central Africa and St. Helena, port unspe...
# 1291                                                 NaN
# 26806                                                NaN
# 17825                                            Badagry
# 5860                                  St. Paul de Loanda
# 4770   Costa de Africa (mainland coast around S Tome/...
# 17360                                                NaN
# 27353                                      Costa da Mina
# 16130                               Sierra Leone estuary
# 16999                                                NaN
# 7271                                              Elmina
# 16170                                             Loango
# 18989                                                NaN
# 9929                                                 NaN
# 34493                                              Bonny
# 26457                                             Whydah
# 12856                                                NaN
# 34939                                                NaN
# 25592                                            Malembo
# 5624                                            Benguela
# 15738                                             Loango
# 17127                                             Gambia
# 26032                                                NaN
# 26506                                      Costa da Mina
# 29207                                                NaN
# 23692                                 St. Paul de Loanda
# 3464                                                 NaN
# 35144                                          Cameroons
# 2377                                        Little Bassa
# 36009                                                NaN
# 12973                                                NaN
# 1877   West Central Africa and St. Helena, port unspe...
# 15441                                                NaN
# 30504                                              Bonny
# 16780  West Central Africa and St. Helena, port unspe...
# 21494                                           São Tomé
# 10053                       Gold Coast, port unspecified
# 16949                                             Whydah
# 12125                                                NaN
#
#                                  PLACCONS     PLACREG  \
# 32064           Prize (taken from French)         NaN
# ...
# 12219     Jamaica, port unspecified     162.0    162.0    200.0       NaN
# 18671                  Cap Français       NaN    351.0    386.0       NaN
# 1291         Cuba, port unspecified       NaN    444.0    490.0       NaN
# 26806                           NaN       NaN    105.0    118.0       NaN
# 17825                    Saint-Marc       NaN    313.0    367.0       NaN
# 5860                            NaN       NaN    479.0    552.0       NaN
# 4770                       San Juan       8.0    208.0    214.0       NaN
# 17360                           NaN       NaN      NaN      NaN       NaN
# 27353       Bahia, port unspecified     334.0    334.0    373.0       NaN
# 16130  Martinique, port unspecified       NaN    174.0    196.0       NaN
# 16999                   Cayes (Les)     337.0    337.0    421.0       NaN
# 7271                       Suriname     405.0    405.0    428.0       NaN
# 16170                  Cap Français     484.0    484.0    700.0       NaN
# 18989                           NaN       NaN    241.0    316.0       NaN
# 9929    St. Kitts, port unspecified       NaN    217.0    271.0       NaN
# 34493   St. Kitts, port unspecified     269.0    269.0    326.0       NaN
# 26457       Bahia, port unspecified     192.0    192.0    210.0       NaN
# 12856                           NaN       NaN    190.0    225.0       NaN
# 34939    Barbados, port unspecified       NaN    328.0    359.0     300.0
# 25592       Bahia, port unspecified      47.0     47.0     54.0       NaN
# 5624                            NaN       NaN    493.0    544.0       NaN
# 15738  Martinique, port unspecified       NaN    414.0    420.0       NaN
# 17127                  Cap Français     137.0    137.0    154.0       NaN
# 26032                           NaN       NaN    417.0    446.0       NaN
# 26506       Bahia, port unspecified       NaN    105.0    118.0       NaN
# 29207    Barbados, port unspecified     160.0    160.0    187.0       NaN
# 23692                  Buenos Aires      73.0    269.0    336.0       NaN
# 3464                            NaN       NaN      NaN      NaN       NaN
# 35144   St. Kitts, port unspecified     183.0    183.0    223.0     300.0
# 2377                       Freetown     184.0    183.0    186.0       NaN
# 36009                           NaN       NaN    533.0    578.0       NaN
# 12973                      Kingston     190.0    190.0    222.0       NaN
# 1877                          Macaé     504.0    504.0    556.0       NaN
# 15441                           NaN       NaN    287.0    359.0     100.0
# 30504    Dominica, port unspecified     239.0    239.0    242.0     246.0
# 16780                  Cap Français     464.0    464.0    510.0       NaN
# 21494  Pernambuco, port unspecified      29.0     29.0     33.0       NaN
# 10053                      Kingston     200.0    200.0    244.0     260.0
# 16949                      Suriname     203.0    203.0    238.0       NaN
# 12125                           NaN       NaN      NaN      NaN       NaN
#
#                                                  SOURCEA  TONMOD  TONNAGE  \
# 32064                                             LR1805   331.0    331.0
# 27747                             APEB, cod. 449, p.117v     NaN      NaN
# 14943                                 Vila Vilar,Cuadro3     NaN      NaN
# 18591                                          mettas,II   398.1    350.0
# 7775                                                BGDB     NaN      NaN
# 4197                                      IUP,ST,47/A/18     NaN      NaN
# 28558                              ANRJ,Codice141,II,224     NaN      NaN
# 11174                              ANRJ, cod. 242, p.93v     NaN      NaN
# 21460                                AHMS, 178.1, p. 218     NaN      NaN
# 22841                                ANC,Fomento,86-3506     NaN      NaN
# 12219                                         T70/14,5,6     NaN      NaN
# 18671                                          mettas,II   299.1    260.0
# 1291                                PP,1845,XLIX:593-633   212.9    165.0
# 26806                             APEB, cod. 439, p.123v     NaN      NaN
# 17825                                          mettas,II   300.0    300.0
# 5860                                Klein,Angola dataset     NaN      NaN
# 4770   AGPR, Protocolos Notariales, Ponce, Otros Func...     NaN      NaN
# 17360                                          mettas,II     NaN    133.0
# 27353                               APEB, cod 443, p.197     NaN      NaN
# 16130                                           mettas,I   128.3     70.0
# 16999                                          mettas,II   304.6    265.0
# 7271                                      Postma,304-401   600.0    300.0
# 16170                                           mettas,I   365.3    250.0
# 18989                                        Roussier,16     NaN      NaN
# 9929                                       Richardson,II   146.3     80.0
# 34493                                      LST,1744-1786   272.3    150.0
# 26457                    AHU,ACL,CU,005, Cx.174, D.13108     NaN      NaN
# 12856                                       PM,17.04.07.     NaN      NaN
# 34939                                      LST,1744-1786   218.3    120.0
# 25592                                     IDO, 22-5-1818     NaN      NaN
# 5624                                         Santos,1973     NaN      NaN
# 15738                                           mettas,I   305.3    200.0
# 17127                                          mettas,II   167.9     92.0
# 26032                       AHU,Angola, Caixa 61, Doc. 2     NaN      NaN
# 26506                        AHU,ACL,CU,005,cx.32,d.2952     NaN      NaN
# 29207                                    CO33/15,5,11,62   236.3    130.0
# 23692                                        Molina, 156     NaN      NaN
# 3464                                     IUP,ST,35/B/241   246.8    159.0
# 35144                                      LST,1744-1786   218.3    120.0
# 2377                                  IUP,ST,12/A2/30-31     NaN      NaN
# 36009                                      JC,31/12/1827     NaN      NaN
# 12973                                          BT6/3,164   146.3     80.0
# 1877                                PP,1845,XLIX:593-633   180.0    180.0
# 15441                     AGI, Contratacion, Legajo 2876     NaN      NaN
# 30504                                             LR1792   148.0    148.0
# 16780                                           mettas,I     NaN    704.0
# 21494                        APEJE, 04.06.18,v.1,p. 111v     NaN      NaN
# 10053                                     Richardson,III   110.3     60.0
# 16949                                           mettas,I     NaN    356.0
# 12125                                          T70/12,14     NaN      NaN
#
#                 TONTYPE  TSLAVESD  VYMRTRAT                 XMIMPFLAG  \
# 32064               NaN       NaN       NaN             Ship, 1801-25
# 27747               NaN       NaN       NaN         Sumaca, 1776-1800
# 14943               NaN       NaN       NaN         Spanish, pre-1626
# 18591            French     250.0      0.00    B. of Benin, 1700-1800
# 7775                NaN     237.0       NaN           Dutch, pre-1650
# 4197                NaN       NaN       NaN           No rig, 1851-66
# 28558               NaN       NaN       NaN        Schooner, pre-1776
# 11174               NaN     470.0      0.05        Curveta, post-1800
# 21460               NaN       NaN       NaN       Schooner, 1776-1800
# 22841               NaN       NaN       NaN             Brig, 1801-25
# 12219               NaN     200.0      0.19     Gold Coast, post-1700
# 18671            French       NaN       NaN      WC Africa, 1701-1800
# 1291            Spanish       NaN       NaN             Brig, 1826-50
# 26806               NaN       NaN       NaN                   Patacho
# 17825            French       NaN       NaN    B. of Benin, 1700-1800
# 5860                NaN     552.0       NaN          Galera, pre-1751
# 4770                NaN       NaN       NaN          Galeta, pre-1826
# 17360            French       NaN       NaN         No rig, 1776-1800
# 27353               NaN       NaN       NaN                   Patacho
# 16130            French       NaN       NaN  Windward Coast, pre-1801
# 16999            French       NaN       NaN           No rig, 1726-50
# 7271              Dutch       NaN       NaN          Dutch, post-1730
# 16170            French     700.0      0.31      WC Africa, 1701-1800
# 18989               NaN       NaN       NaN          French, pre-1716
# 9929   English pre-1775       NaN       NaN           No rig, 1726-50
# 34493  English pre-1775       NaN      0.17             Ship, 1751-75
# 26457               NaN       NaN       NaN        Curveta, 1776-1800
# 12856               NaN       NaN       NaN           No rig, 1701-25
# 34939  English pre-1775       NaN       NaN           Ship, 1776-1800
# 25592               NaN       NaN       NaN         Schooner, 1801-25
# 5624                NaN     544.0       NaN       Bergantine, 1801-25
# 15738            French     420.0      0.01      WC Africa, 1701-1800
# 17127            French       NaN       NaN     Senegambia, 1701-1800
# 26032               NaN       NaN       NaN          Curveta, 1751-75
# 26506               NaN       NaN       NaN                   Patacho
# 29207  English pre-1775       NaN       NaN            Ship, pre-1726
# 23692               NaN       NaN       NaN         Spanish, pre-1626
# 3464          English 2       NaN       NaN         Schooner, 1826-50
# 35144  English pre-1775       NaN       NaN             Ship, 1751-75
# 2377                NaN     186.0      0.02           Galeta, 1826-50
# 36009               NaN       NaN       NaN           Galera, 1826-50
# 12973  English pre-1775       NaN       NaN             Snow, 1751-75
# 1877         Portuguese       NaN       NaN             Brig, 1826-50
# 15441               NaN       NaN       NaN         Spanish, pre-1626
# 30504         English 1       NaN      0.01           Ship, 1776-1800
# 16780            French       NaN       NaN      WC Africa, 1701-1800
# 21494               NaN       NaN       NaN         Schooner, 1801-25
# 10053  English pre-1775       NaN       NaN             Snow, 1726-50
# 16949            French       NaN       NaN    B. of Benin, 1700-1800
# 12125               NaN       NaN       NaN         No rig, 1676-1700
#
#                  YEAR5           YEAR10           YEAR25  YEAR100  YEARAF  \
# 32064    years 1801-05    years 1801-10    years 1801-25   1800.0  1804.0
# 27747    years 1776-80  years 1771-1780  years 1776-1800   1700.0  1776.0
# 14943    years 1616-20    years 1611-20    years 1601-25   1600.0  1619.0
# 18591    years 1716-20    years 1711-20    years 1701-25   1700.0  1719.0
# 7775     years 1636-40    years 1631-40    years 1626-50   1600.0  1637.0
# 4197     years 1861-65    years 1861-70    years 1851-75   1800.0  1861.0
# 28558    years 1726-30    years 1721-30    years 1726-50   1700.0  1726.0
# 11174    years 1801-05    years 1801-10    years 1801-25   1800.0  1803.0
# 21460  years 1796-1800  years 1791-1800  years 1776-1800   1700.0  1798.0
# 22841    years 1806-10    years 1801-10    years 1801-25   1800.0  1810.0
# 12219    years 1701-05    years 1701-10    years 1701-25   1700.0  1704.0
# 18671    years 1751-55    years 1751-60    years 1751-75   1700.0  1753.0
# 1291     years 1831-35    years 1831-40    years 1826-50   1800.0  1834.0
# 26806    years 1691-95  years 1691-1700  years 1676-1700   1600.0  1694.0
# 17825    years 1776-80  years 1771-1780  years 1776-1800   1700.0  1776.0
# 5860     years 1736-40    years 1731-40    years 1726-50   1700.0  1738.0
# 4770     years 1816-20    years 1811-20    years 1801-25   1800.0  1818.0
# 17360    years 1791-95  years 1791-1800  years 1776-1800   1700.0  1793.0
# 27353    years 1731-35    years 1731-40    years 1726-50   1700.0  1734.0
# 16130    years 1746-50    years 1741-50    years 1726-50   1700.0  1750.0
# 16999    years 1736-40    years 1731-40    years 1726-50   1700.0  1740.0
# 7271     years 1756-60    years 1751-60    years 1751-75   1700.0  1756.0
# 16170    years 1751-55    years 1751-60    years 1751-75   1700.0  1752.0
# 18989    years 1681-85    years 1681-90  years 1676-1700   1600.0  1685.0
# 9929     years 1741-45    years 1741-50    years 1726-50   1700.0  1742.0
# 34493    years 1756-60    years 1751-60    years 1751-75   1700.0  1758.0
# 26457    years 1776-80  years 1771-1780  years 1776-1800   1700.0  1777.0
# 12856    years 1716-20    years 1711-20    years 1701-25   1700.0  1717.0
# 34939    years 1776-80  years 1771-1780  years 1776-1800   1700.0  1777.0
# 25592    years 1816-20    years 1811-20    years 1801-25   1800.0  1818.0
# 5624     years 1801-05    years 1801-10    years 1801-25   1800.0  1802.0
# 15738    years 1721-25    years 1721-30    years 1701-25   1700.0  1722.0
# 17127    years 1771-75  years 1771-1780    years 1751-75   1700.0  1771.0
# 26032    years 1771-75  years 1771-1780    years 1751-75   1700.0  1775.0
# 26506    years 1726-30    years 1721-30    years 1726-50   1700.0  1728.0
# 29207    years 1716-20    years 1711-20    years 1701-25   1700.0  1717.0
# 23692    years 1611-15    years 1611-20    years 1601-25   1600.0  1612.0
# 3464     years 1846-50    years 1841-50    years 1826-50   1800.0  1847.0
# 35144    years 1771-75  years 1771-1780    years 1751-75   1700.0  1774.0
# 2377     years 1826-30    years 1821-30    years 1826-50   1800.0  1830.0
# 36009    years 1826-30    years 1821-30    years 1826-50   1800.0  1827.0
# 12973    years 1766-70    years 1761-70    years 1751-75   1700.0  1766.0
# 1877     years 1836-40    years 1831-40    years 1826-50   1800.0  1839.0
# 15441    years 1606-10    years 1601-10    years 1601-25   1600.0  1609.0
# 30504    years 1791-95  years 1791-1800  years 1776-1800   1700.0  1792.0
# 16780    years 1786-90    years 1781-91  years 1776-1800   1700.0  1788.0
# 21494    years 1821-25    years 1821-30    years 1801-25   1800.0  1823.0
# 10053    years 1746-50    years 1741-50    years 1726-50   1700.0  1748.0
# 16949    years 1791-95  years 1791-1800  years 1776-1800   1700.0  1792.0
# 12125    years 1681-85    years 1681-90  years 1676-1700   1600.0  1685.0
#
#        YEARAM  YEARDEP
# 32064  1804.0   1804.0
# 27747  1776.0   1776.0
# 14943  1619.0   1617.0
# 18591  1719.0   1718.0
# 7775   1637.0   1637.0
# 4197   1861.0   1861.0
# 28558  1726.0   1726.0
# 11174  1804.0   1802.0
# 21460  1798.0   1798.0
# 22841  1810.0   1810.0
# 12219  1704.0   1703.0
# 18671  1754.0   1753.0
# 1291   1834.0   1834.0
# 26806  1694.0   1694.0
# 17825  1777.0   1776.0
# 5860   1738.0   1737.0
# 4770   1818.0   1818.0
# 17360  1793.0   1792.0
# 27353  1734.0   1733.0
# 16130  1750.0   1749.0
# 16999  1740.0   1738.0
# 7271   1757.0   1756.0
# 16170  1752.0   1751.0
# 18989  1685.0   1685.0
# 9929   1742.0   1742.0
# 34493  1758.0   1757.0
# 26457  1777.0   1777.0
# 12856  1717.0   1717.0
# 34939  1777.0   1776.0
# 25592  1818.0   1818.0
# 5624   1802.0   1802.0
# 15738  1722.0   1722.0
# 17127  1771.0   1771.0
# 26032  1775.0   1775.0
# 26506  1728.0   1728.0
# 29207  1717.0   1717.0
# 23692  1612.0   1612.0
# 3464   1847.0   1847.0
# 35144  1774.0   1774.0
# 2377   1830.0   1829.0
# 36009  1827.0   1827.0
# 12973  1766.0   1765.0
# 1877   1839.0   1839.0
# 15441  1609.0   1609.0
# 30504  1792.0   1791.0
# 16780  1788.0   1787.0
# 21494  1823.0   1823.0
# 10053  1748.0   1748.0
# 16949  1792.0   1791.0
# 12125  1685.0   1685.0

# %%
df = df.drop(columns = ['ADLT1IMP', 'CHILRAT1', 'GIRL1' , 'REGDIS2', 'REGEM2','REGEM3', 'REGISREG', 'RETRNREG', 'RETRNREG1' ])

# %%
df.shape
# Out:
# (36108, 61)

# %% [markdown]
# #### Checking the data types

# %% [markdown]
# **Since all numerical data as basically integers in the dataset,
# I will go ahead and convert float64 to int32**

# %%
df_int = [ col for col in df if df[col].dtype == 'float64']

# %%
df_int
# Out:
# ['VOYAGEID',
#  'DATARR34',
#  'DATEDEP',
#  'DATEDEPA',
#  'DATEDEPAM',
#  'DATEDEPB',
#  'DATEDEPC',
#  'DATEEND',
#  'GUNS',
#  'SLAARRIV',
#  'SLAMIMP',
#  'SLAXIMP',
#  'SLINTEND',
#  'TONMOD',
#  'TONNAGE',
#  'TSLAVESD',
#  'VYMRTRAT',
#  'YEAR100',
#  'YEARAF',
#  'YEARAM',
#  'YEARDEP']

# %%
df['VOYAGEID'] = df['VOYAGEID'].astype('int32')

# %%
df_cat = [ col for col in df if df[col].dtype == 'object' and 'category']

# %%
df_cat
# Out:
# ['CAPTAINA', 'EVGREEN', 'OWNERA', 'SHIPNAME', 'SOURCEA']

# %%
df.dtypes
# Out:
# VOYAGEID          int32
# ADPSALE1       category
# ARRPORT        category
# CAPTAINA         object
# DATARR34        float64
# DATEDEP         float64
# DATEDEPA        float64
# DATEDEPAM       float64
# DATEDEPB        float64
# DATEDEPC        float64
# DATEEND         float64
# DEPTREGIMP     category
# DEPTREGIMP1    category
# EVGREEN          object
# FATE           category
# FATE2          category
# FATE3          category
# FATE4          category
# GUNS            float64
# MAJBUYPT       category
# MAJBYIMP       category
# MAJBYIMP1      category
# MAJSELPT       category
# MJBYPTIMP      category
# MJSELIMP       category
# MJSELIMP1      category
# MJSLPTIMP      category
# NATINIMP       category
# NATIONAL       category
# OWNERA           object
# PLAC1TRA       category
# PLACCONS       category
# PLACREG        category
# PORTDEP        category
# PORTRET        category
# PTDEPIMP       category
# REGARR         category
# REGDIS1        category
# REGEM1         category
# RESISTANCE     category
# RIG            category
# SHIPNAME         object
# SLA1PORT       category
# SLAARRIV        float64
# SLAMIMP         float64
# SLAXIMP         float64
# SLINTEND        float64
# SOURCEA          object
# TONMOD          float64
# TONNAGE         float64
# TONTYPE        category
# TSLAVESD        float64
# VYMRTRAT        float64
# XMIMPFLAG      category
# YEAR5          category
# YEAR10         category
# YEAR25         category
# YEAR100         float64
# YEARAF          float64
# YEARAM          float64
# YEARDEP         float64
# dtype: object

# %% [markdown]
# ### Analyzing the Content of a Categorical Variable

# %%
## Number of Countries/Territories where Ships were registered

# %%
df['NATIONAL'].nunique()
# Out:
# 20

# %%
df['NATIONAL']
# Out:
# 0        Portugal
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 36103    Portugal
# 36104      France
# 36105         NaN
# 36106    Portugal
# 36107         NaN
# Name: NATIONAL, Length: 36108, dtype: category
# Categories (20, object): [25, Argentina, Brazil, Denmark, ..., Spain / Uruguay, Sweden, USA, Uruguay]

# %%
df['NATIONAL'].unique()
# Out:
# [Portugal, NaN, Sweden, Spain, France, ..., Great Britain, 25, Spain / Uruguay, Portugal / Brazil, Genoa]
# Length: 21
# Categories (20, object): [Portugal, Sweden, Spain, France, ..., 25, Spain / Uruguay, Portugal / Brazil, Genoa]

# %%
obj_df = df.select_dtypes(include = 'object')

# %%
# Create a function to describ

# %%
import altair as alt

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
df['NATIONAL'].value_counts(dropna= False, normalize = False)
# Out:
# Great Britain               11239
# NaN                          9538
# Portugal                     5332
# France                       4090
# USA                          1799
# Spain                        1637
# Netherlands                  1249
# Brazil                        792
# Denmark                       311
# Hanse Towns, Brandenburg       61
# Sweden                         16
# Spain / Uruguay                15
# Uruguay                         8
# Mexico                          6
# Portugal / Brazil               6
# Sardinia                        3
# Argentina                       2
# Norway                          1
# Genoa                           1
# Russia                          1
# 25.0                            1
# Name: NATIONAL, dtype: int64

# %%
source = pd.DataFrame({'Flag': ['Great Britain','Unspecified',                          
'Portugal',                     
'France' ,                      
'USA',                         
'Spain',                      
'Netherlands',                 
'Brazil',                     
'Denmark',                    
'Hanse Towns, Brandenburg',
'Sweden',                      
'Spain / Uruguay',                
'Uruguay',
'Mexico',                          
'Portugal / Brazil',               
'Sardinia',                        
'Argentina',                       
'Norway',                          
'Genoa',                           
'Russia',                          
'Unknown'],
'Values': [11239, 9538, 5332, 4090,
 1799,
 1637,
 1249,
 792,
 311,
 61,
 16,
 15,
 8,
 6,
 6,
 3,
 2,
 1,
 1,
 1,
 1]})

alt.Chart(source).transform_joinaggregate(
    TotalFlags='sum(Values)',
).transform_calculate(
    PercentOfTotal="datum.Values / datum.TotalFlags"
).mark_bar().encode(
    alt.X('PercentOfTotal:Q', axis=alt.Axis(format='.0%')),
    y='Flag:N'
)
# Out:
# alt.Chart(...)

# %%
from statistics import mode

# %%
df['SHIPNAME'].value_counts(dropna= True)
# Out:
#                                      1636
# Mary                                  254
# Nancy                                 197
# NS do Rosario S Antônio e Almas       182
# NS da Conceição S Antônio e Almas     175
#                                      ...
# Que Lhe Importa                         1
# Julien                                  1
# City of Norfolk                         1
# Betty and Peggy                         1
# Whidah Gally                            1
# Name: SHIPNAME, Length: 9441, dtype: int64

# %% [markdown]
# ### Most Common Ship names
#
# Mary :                                 254
#
# Nancy:                                 197
#
# NS do Rosario S Antônio e Almas:       182
#
# NS da Conceição S Antônio e Almas:     175

# %%
df['SHIPNAME'].sample(10)
# Out:
# 16311                                 Saint Hilaire
# 19119                                        Cybèle
# 27858    NS da Ajuda S Francisco de Paula e Antônio
# 23923                                Aurora do Cabo
# 17873                                    Bellecombe
# 8323                                         Carlos
# 26987             NS de Guadalupe Almas e S Antônio
# 7237                                   Huis ter Mee
# 26806              Espírito Santo e NS da Conceição
# 28297                     S Estevão e NS das Brotas
# Name: SHIPNAME, dtype: object

# %% [markdown]
#  **SHIPS FLEW THE FLAG OF THE TERRITORY WHERE THEY WERE CONSTRUCTED**

# %%
df.groupby(['PLACCONS', 'NATIONAL'])['PLACCONS', 'NATIONAL'].count().dropna().sample(50)
# Out:
# /Users/wilfriedzoungrana/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                                 PLACCONS  NATIONAL
# PLACCONS                         NATIONAL
# Providence                       USA                 5.0       5.0
# Dublin                           Great Britain      28.0      28.0
# Salisbury                        Great Britain       4.0       4.0
# Chatham                          Great Britain       2.0       2.0
# Marcus Hook                      Great Britain       4.0       4.0
# Galway                           USA                 1.0       1.0
# Great Britain, port unspecified  France             19.0      19.0
# Ramsgate                         Great Britain       4.0       4.0
# Mediterranean, port unspecified  Spain               1.0       1.0
# Bayonne                          France              9.0       9.0
# Stockton                         Great Britain       2.0       2.0
# Dighton                          USA                 1.0       1.0
# Bahamas, port unspecified        Great Britain       2.0       2.0
# Cadiz                            Great Britain       1.0       1.0
# Weymouth                         USA                 2.0       2.0
# Bermuda                          USA                 5.0       5.0
# London                           France              2.0       2.0
# Netherlands, port unspecified    Portugal            1.0       1.0
# Airth                            Great Britain       3.0       3.0
# Great Britain, port unspecified  Portugal            2.0       2.0
# Portugal, port unspecified       Spain               3.0       3.0
# Connecticut, port unspecified    USA                 4.0       4.0
# South Carolina, port unspecified USA                 1.0       1.0
# Shields                          Great Britain       1.0       1.0
# Ilfracombe                       Great Britain       2.0       2.0
# Pamunkey                         Great Britain       6.0       6.0
# Maryport                         Great Britain       1.0       1.0
# Hyde County                      Great Britain       3.0       3.0
# Amesbury                         USA                 2.0       2.0
# Dunkerque                        France              2.0       2.0
# Portugal, port unspecified       Brazil              2.0       2.0
# Bristol (RI)                     USA                 1.0       1.0
# Scotland, port unspecified       Great Britain       2.0       2.0
# USA, location unspecified        Portugal           41.0      41.0
# Cowes                            Great Britain      14.0      14.0
# Amsterdam                        Great Britain       3.0       3.0
# Elizabeth River                  Great Britain      15.0      15.0
# Wexford                          Great Britain       2.0       2.0
# Bristol                          Great Britain     315.0     315.0
# Deptford                         Great Britain       2.0       2.0
# Guildford                        USA                 1.0       1.0
# Nantes                           France            164.0     164.0
# Vannes                           Great Britain       1.0       1.0
# Brest                            France              2.0       2.0
# North Carolina, port unspecified Great Britain      26.0      26.0
# Rye                              Great Britain       1.0       1.0
# New Providence                   Great Britain      18.0      18.0
# Wharton                          Great Britain       2.0       2.0
# Calcutta                         Great Britain       2.0       2.0
# Providence                       Great Britain       6.0       6.0

# %%
# Which rig type was the most common?

# %%
df['RIG'].value_counts(dropna = False).head(20)
# Out:
# NaN               12414
# Ship               4854
# Brig               2893
# Schooner           2374
# Bergantim          1945
# Curveta            1882
# Snauw              1444
# Galera             1231
# Brigantine         1177
# Sumaca             1142
# Sloop               738
# Patacho             607
# Navio mercante      553
# Fregat              429
# Galeta              317
# Não                 290
# Barque              252
# Fregata             226
# Schooner-brig       141
# Yaght                85
# Name: RIG, dtype: int64

# %%
source1 = df[['RIG', 'NATIONAL']]

# %%
source1 = pd.DataFrame({'Rig': ['Unknown','Ship',                          
'Brig',                     
'Schooner' ,                      
'Bergantim',                         
'Curveta',                      
'Snauw',                 
'Galera',                     
'Brigantine',                    
'Sumaca',
'Sloop',                      
'Patacho',                
'Navio mercante',
'Fregat',                          
'Galeta',               
'Não',                        
'Barque',                       
'Fregata',                          
'Schooner-brig',                           
'Yaght'],
'Values': [12414,
 4854,
 2893,
 2374,
 1945,
 1882,
 1444,
 1231,
 1177,
 1142,
 738,
 607,
 553,
 429,
 317,
 290,
 252,
 226,
 141,
 85]})

# %%
source1
# Out:
#                Rig  Values
# 0          Unknown   12414
# 1             Ship    4854
# 2             Brig    2893
# 3         Schooner    2374
# 4        Bergantim    1945
# 5          Curveta    1882
# 6            Snauw    1444
# 7           Galera    1231
# 8       Brigantine    1177
# 9           Sumaca    1142
# 10           Sloop     738
# 11         Patacho     607
# 12  Navio mercante     553
# 13          Fregat     429
# 14          Galeta     317
# 15             Não     290
# 16          Barque     252
# 17         Fregata     226
# 18   Schooner-brig     141
# 19           Yaght      85

# %%
alt.Chart(source1).mark_bar().encode(
    x= 'Values:Q',
    y= 'Rig:O'
)
# Out:
# alt.Chart(...)

# %%
# Who owned the most ventures? Check variable OWNERA--->

# %%
m = df['OWNERA'].value_counts(dropna = False,).head(20)

# %%
list(m)
# Out:
# [14426,
#  647,
#  439,
#  179,
#  157,
#  123,
#  122,
#  115,
#  112,
#  109,
#  104,
#  96,
#  96,
#  90,
#  78,
#  76,
#  72,
#  70,
#  66,
#  65]

# %%
m.keys()
# Out:
# Index(['', 'Royal African Company', 'West-Indische Compagnie',
#        'Companhia Geral do Grão Pará e Maranhão',
#        'Companhia Geral de Pernambuco e Paraíba', 'James, William',
#        'Compagnie des Indes', 'South Sea Company',
#        'Middelburgsche Commercie Compagnie', 'Boats, William',
#        'Company of Royal Adventurers', 'Compagnie du Sénégal',
#        'Laroche, James*', 'Case, George', 'Tarleton, John',
#        'Ferreira, João Antônio', 'Dawson, John', 'Leyland, Thomas',
#        'Harper, William', 'Davenport, William'],
#       dtype='object')

# %%
source2=  pd.DataFrame({'Vessel Owner': ['Unspecified','Royal African Company', 'West-Indische Compagnie',
       'Companhia Geral do Grão Pará e Maranhão',
       'Companhia Geral de Pernambuco e Paraíba', 'James, William',
       'Compagnie des Indes', 'South Sea Company',
       'Middelburgsche Commercie Compagnie', 'Boats, William',
       'Company of Royal Adventurers', 'Laroche, James*',
       'Compagnie du Sénégal', 'Case, George', 'Tarleton, John',
       'Ferreira, João Antônio', 'Dawson, John', 'Leyland, Thomas',
       'Harper, William', 'Davenport, William'],
      'Values': [12414, 4854, 2893, 2374, 1945, 1882, 1444, 1231, 1177,1142,
 738,
 607,
 553,
 429,
 317,
 290,
 252,
 226,
 141,
 85]})

# %%
alt.Chart(source2).mark_bar().encode(
    x= 'Values:Q',
    y= 'Vessel Owner:O'
)
# Out:
# alt.Chart(...)

# %% [markdown]
#  #### Percentage of voyages completed as intended(FATE 1 == 1), shipwrecked, captured by pirates, British

# %%
s= df['FATE'].value_counts().head(25)

# %%
source3 = pd.DataFrame({'Fate': s.keys(),
      'Values': list(s)})

# %%
alt.Chart(source3).transform_joinaggregate(
    TotalFate='sum(Values)',
).transform_calculate(
    PercentOfTotal="datum.Values / datum.TotalFate"
).mark_bar().encode(
    alt.X('PercentOfTotal:Q', axis=alt.Axis(format='.0%')),
    y='Fate:N'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# 9. Outcome for slaves ---> FATE2, most common fate for slaves

# %% [markdown]
# Outcome for slaves ---> FATE2, most common fate for slaves

# %%
d = df['FATE2'].value_counts().head(25)

# %%
d
# Out:
# Slaves disembarked Americas                            26009
# Slaves embarked, transhipped or no further record       3780
# No information on slaves                                3738
# No slaves embarked                                      1589
# Slaves disembarked in Africa/Europe                      679
# Slaves perished with ship                                269
# Slaves embarked but not disemb in Europe or America       44
# Name: FATE2, dtype: int64

# %%
source4 = pd.DataFrame({'Fate for the Slaves': d.keys(),
      'Values': list(d)})

# %%
alt.Chart(source4).transform_joinaggregate(
    TotalFate2='sum(Values)',
).transform_calculate(
    PercentOfTotal="datum.Values / datum.TotalFate2"
).mark_bar().encode(
    alt.X('PercentOfTotal:Q', axis=alt.Axis(format='.0%')),
    y='Fate for the Slaves:N'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# . Outcome of voyage if vessel captured? FATE3 --->
#
# 11. Outcome of voyage for owners -> FATE 4 --> 'Luckiest owner'?

# %%
c = df['FATE3'].value_counts().head(25)

# %%
c
# Out:
# Not captured               27443
# Unknown                     3722
# British                     1847
# Natural hazard              1412
# French                       727
# African                      195
# Captor unspecified           178
# pirate/privateer action      132
# Dutch                        117
# Spanish                       99
# US                            99
# Portuguese                    76
# Brazil                        31
# Crew action                   23
# Venezuela                      3
# Haitians                       3
# Sweden                         1
# Name: FATE3, dtype: int64

# %%
source5 = pd.DataFrame({'Fate for the Vessel': c.keys(),
      'Values': list(c)})

# %%
alt.Chart(source5).transform_joinaggregate(
    TotalFate3='sum(Values)',
).transform_calculate(
    PercentOfTotal="datum.Values / datum.TotalFate3"
).mark_bar().encode(
    alt.X('PercentOfTotal:Q', axis=alt.Axis(format='.0%')),
    y='Fate for the Vessel:N'
)
# Out:
# alt.Chart(...)

# %%
e = df['PORTDEP'].value_counts().head(25)

# %%
e
# Out:
# Liverpool                         4968
# Bahia, port unspecified           3758
# London                            3107
# Rio de Janeiro                    2304
# Bristol                           2079
# Nantes                            1731
# Havana                            1137
# Lisbon                            1094
# Pernambuco, port unspecified      1023
# Rhode Island, port unspecified     605
# La Rochelle                        481
# Vlissingen                         453
# Le Havre                           451
# Bordeaux                           444
# Texel                              392
# Barbados, port unspecified         336
# Zeeland                            313
# San Lucar                          292
# Newport                            228
# Charleston                         227
# Saint-Malo                         218
# Cadiz                              191
# New York, port unspecified         184
# Boston                             170
# Seville                            154
# Name: PORTDEP, dtype: int64

# %%
df.to_csv('voyages.csv', index = False)
